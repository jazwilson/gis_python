# %% [markdown]
# # Chapter 5/ exercise 5

# %% [markdown]
# ## Chapter 5 notes : Pandas

# %%
import pandas as pd

# %%
# read file
url = (
    "https://geo-python.github.io/2017/_static/data/L5/Kumpula-June-2016-w-metadata.txt"
)
data = pd.read_csv(url, skiprows=8)
data.head()
# Out:
#    YEARMODA  TEMP   MAX   MIN
# 0  20160601  65.5  73.6  54.7
# 1  20160602  65.8  80.8  55.0
# 2  20160603  68.4  77.9  55.6
# 3  20160604  57.5  70.9  47.3
# 4  20160605  51.4  58.3  43.2

# %% [markdown]
# - read_pickle for reading data stored in python pickle format

# %%
# load specific cols
temp_data = pd.read_csv(url, skiprows=8, usecols=["YEARMODA", "TEMP"])
temp_data.head()
# Out:
#    YEARMODA  TEMP
# 0  20160601  65.5
# 1  20160602  65.8
# 2  20160603  68.4
# 3  20160604  57.5
# 4  20160605  51.4

# %%
type(temp_data)
# Out:
# pandas.core.frame.DataFrame

# %%
# print col names
data.columns.values
# Out:
# array(['YEARMODA', 'TEMP', 'MAX', 'MIN'], dtype=object)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
data.dtypes
# Out:
# YEARMODA      int64
# TEMP        float64
# MAX         float64
# MIN         float64
# dtype: object

# %%
# no of cols in df
len(data.columns)
# Out:
# 4

# %%
# selecting cols

selection = data[["YEARMODA", "TEMP"]]
selection.head()
# Out:
#    YEARMODA  TEMP
# 0  20160601  65.5
# 1  20160602  65.8
# 2  20160603  68.4
# 3  20160604  57.5
# 4  20160605  51.4

# %%
# access single col
data["TEMP"]
# Out:
# 0     65.5
# 1     65.8
# 2     68.4
# 3     57.5
# 4     51.4
# 5     52.2
# 6     56.9
# 7     54.2
# 8     49.4
# 9     49.5
# 10    54.0
# 11    55.4
# 12    58.3
# 13    59.7
# 14    63.4
# 15    57.8
# 16    60.4
# 17    57.3
# 18    56.3
# 19    59.3
# 20    62.6
# 21    61.7
# 22    60.9
# 23    61.1
# 24    65.7
# 25    69.6
# 26    60.7
# 27    65.4
# 28    65.8
# 29    65.7
# Name: TEMP, dtype: float64

# %% [markdown]
# Descriptive statistics

# %%
# mean
data["TEMP"].mean()
# Out:
# 59.730000000000004

# %%
# mean for all cols
data.mean()
# Out:
# YEARMODA    20160615.50
# TEMP              59.73
# MAX               67.94
# MIN               51.75
# dtype: float64

# %%
data.describe()
# Out:
#            YEARMODA       TEMP        MAX        MIN
# count  3.000000e+01  30.000000  30.000000  30.000000
# mean   2.016062e+07  59.730000  67.940000  51.750000
# std    8.803408e+00   5.475472   6.651761   5.634484
# min    2.016060e+07  49.400000  54.100000  41.700000
# 25%    2.016061e+07  56.450000  63.150000  47.300000
# 50%    2.016062e+07  60.050000  69.000000  54.050000
# 75%    2.016062e+07  64.900000  72.375000  55.750000
# max    2.016063e+07  69.600000  80.800000  60.300000

# %%
# for temp, max, min

data[["TEMP", "MAX", "MIN"]].describe()
# Out:
#             TEMP        MAX        MIN
# count  30.000000  30.000000  30.000000
# mean   59.730000  67.940000  51.750000
# std     5.475472   6.651761   5.634484
# min    49.400000  54.100000  41.700000
# 25%    56.450000  63.150000  47.300000
# 50%    60.050000  69.000000  54.050000
# 75%    64.900000  72.375000  55.750000
# max    69.600000  80.800000  60.300000

# %% [markdown]
# Plots

# %%
data[["TEMP", "MAX", "MIN"]].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# From lists to pandas objects

# %%
# Create pandas Series from a list

number_series = pd.Series([4, 5, 6, 7.0])
print(number_series)
# Out:
# 0    4.0
# 1    5.0
# 2    6.0
# 3    7.0
# dtype: float64

# %%
# set a custom index
number_series = pd.Series([4, 5, 6, 7.0], index=["a", "b", "c", "d"])
print(number_series)
# Out:
# a    4.0
# b    5.0
# c    6.0
# d    7.0
# dtype: float64

# %%
# Station names
stations = [
    "Hanko Russarö",
    "Heinola Asemantaus",
    "Helsinki Kaisaniemi",
    "Helsinki Malmi airfield",
]

# Latitude coordinates of Weather stations
lats = [59.77, 61.2, 60.18, 60.25]

# Longitude coordinates of Weather stations
lons = [22.95, 26.05, 24.94, 25.05]

# %%
new_data = pd.DataFrame(data={"station_name": stations, "lat": lats, "lon": lons})
new_data
# Out:
#               station_name    lat    lon
# 0            Hanko Russarö  59.77  22.95
# 1       Heinola Asemantaus  61.20  26.05
# 2      Helsinki Kaisaniemi  60.18  24.94
# 3  Helsinki Malmi airfield  60.25  25.05

# %%
# empty df

df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Processing data with pandas

# %%
# read file
url = (
    "https://geo-python.github.io/2017/_static/data/L5/Kumpula-June-2016-w-metadata.txt"
)
data = pd.read_csv(url, skiprows=8)
data.head()
# Out:
#    YEARMODA  TEMP   MAX   MIN
# 0  20160601  65.5  73.6  54.7
# 1  20160602  65.8  80.8  55.0
# 2  20160603  68.4  77.9  55.6
# 3  20160604  57.5  70.9  47.3
# 4  20160605  51.4  58.3  43.2

# %%
# New col
data["DIFF"] = 0.0
data.head()
# Out:
#    YEARMODA  TEMP   MAX   MIN  DIFF
# 0  20160601  65.5  73.6  54.7   0.0
# 1  20160602  65.8  80.8  55.0   0.0
# 2  20160603  68.4  77.9  55.6   0.0
# 3  20160604  57.5  70.9  47.3   0.0
# 4  20160605  51.4  58.3  43.2   0.0

# %%
# update with calculattion
data["DIFF"] = data["MAX"] - data["MIN"]
data.head()
# Out:
#    YEARMODA  TEMP   MAX   MIN  DIFF
# 0  20160601  65.5  73.6  54.7  18.9
# 1  20160602  65.8  80.8  55.0  25.8
# 2  20160603  68.4  77.9  55.6  22.3
# 3  20160604  57.5  70.9  47.3  23.6
# 4  20160605  51.4  58.3  43.2  15.1

# %%
# Create a new column and convert temp fahrenheit to celsius:
data["TEMP_CELSIUS"] = (data["TEMP"] - 32) / (9 / 5)
data.head()
# Out:
#    YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS
# 0  20160601  65.5  73.6  54.7  18.9     18.611111
# 1  20160602  65.8  80.8  55.0  25.8     18.777778
# 2  20160603  68.4  77.9  55.6  22.3     20.222222
# 3  20160604  57.5  70.9  47.3  23.6     14.166667
# 4  20160605  51.4  58.3  43.2  15.1     10.777778

# %%
# Calculate the temperatures in Kelvins using the Celsius values and store the result a new column calle TEMP_KELVIN in our dataframe.

data["TEMP_KELVIN"] = data["TEMP_CELSIUS"] + 273.15
data.head()
# Out:
#    YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS  TEMP_KELVIN
# 0  20160601  65.5  73.6  54.7  18.9     18.611111   291.761111
# 1  20160602  65.8  80.8  55.0  25.8     18.777778   291.927778
# 2  20160603  68.4  77.9  55.6  22.3     20.222222   293.372222
# 3  20160604  57.5  70.9  47.3  23.6     14.166667   287.316667
# 4  20160605  51.4  58.3  43.2  15.1     10.777778   283.927778

# %%
# look at first 5 rows
selection = data[0:5]
selection
# Out:
#    YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS  TEMP_KELVIN
# 0  20160601  65.5  73.6  54.7  18.9     18.611111   291.761111
# 1  20160602  65.8  80.8  55.0  25.8     18.777778   291.927778
# 2  20160603  68.4  77.9  55.6  22.3     20.222222   293.372222
# 3  20160604  57.5  70.9  47.3  23.6     14.166667   287.316667
# 4  20160605  51.4  58.3  43.2  15.1     10.777778   283.927778

# %%
# first 5 rows for col Tempt
selection = data.loc[0:5, "TEMP"]
selection
# Out:
# 0    65.5
# 1    65.8
# 2    68.4
# 3    57.5
# 4    51.4
# 5    52.2
# Name: TEMP, dtype: float64

# %%
# Multi col: pass through (.loc[start_index:stop_index, list_of_columns])

selection = data.loc[0:5, ["TEMP", "TEMP_CELSIUS"]]
selection
# Out:
#    TEMP  TEMP_CELSIUS
# 0  65.5     18.611111
# 1  65.8     18.777778
# 2  68.4     20.222222
# 3  57.5     14.166667
# 4  51.4     10.777778
# 5  52.2     11.222222

# %%
#  mean temperatures (in Celsius) for the last seven days of June

temp_sel = data.loc[23:29, "TEMP_CELSIUS"].mean()
temp_sel
# Out:
# 18.253968253968257

# %%
# can also use iloc to refer to cols
data.iloc[0:5, 0:2]
# Out:
#    YEARMODA  TEMP
# 0  20160601  65.5
# 1  20160602  65.8
# 2  20160603  68.4
# 3  20160604  57.5
# 4  20160605  51.4

# %% [markdown]
# Filtering and updating data

# %%
# is temp greater than 15 C degrees
data["TEMP_CELSIUS"] > 15
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14     True
# 15    False
# 16     True
# 17    False
# 18    False
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# Name: TEMP_CELSIUS, dtype: bool

# %%
# Select rows with temp celsius higher than 15 degrees
warm_temps = data.loc[data["TEMP_CELSIUS"] > 15]
warm_temps
# Out:
#     YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS  TEMP_KELVIN
# 0   20160601  65.5  73.6  54.7  18.9     18.611111   291.761111
# 1   20160602  65.8  80.8  55.0  25.8     18.777778   291.927778
# 2   20160603  68.4  77.9  55.6  22.3     20.222222   293.372222
# 13  20160614  59.7  67.8  47.8  20.0     15.388889   288.538889
# 14  20160615  63.4  70.3  49.3  21.0     17.444444   290.594444
# 16  20160617  60.4  70.7  55.9  14.8     15.777778   288.927778
# 19  20160620  59.3  69.1  52.2  16.9     15.166667   288.316667
# 20  20160621  62.6  71.4  50.4  21.0     17.000000   290.150000
# 21  20160622  61.7  70.2  55.4  14.8     16.500000   289.650000
# 22  20160623  60.9  67.1  54.9  12.2     16.055556   289.205556
# 23  20160624  61.1  68.9  56.7  12.2     16.166667   289.316667
# 24  20160625  65.7  75.4  57.9  17.5     18.722222   291.872222
# 25  20160626  69.6  77.7  60.3  17.4     20.888889   294.038889
# 26  20160627  60.7  70.0  57.6  12.4     15.944444   289.094444
# 27  20160628  65.4  73.0  55.8  17.2     18.555556   291.705556
# 28  20160629  65.8  73.2  59.7  13.5     18.777778   291.927778
# 29  20160630  65.7  72.7  59.2  13.5     18.722222   291.872222

# %%
# Select rows with temp celsius higher than 15 degrees from late June 2016
warm_temps = data.loc[(data["TEMP_CELSIUS"] > 15) & (data["YEARMODA"] >= 20160615)]

warm_temps
# Out:
#     YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS  TEMP_KELVIN
# 14  20160615  63.4  70.3  49.3  21.0     17.444444   290.594444
# 16  20160617  60.4  70.7  55.9  14.8     15.777778   288.927778
# 19  20160620  59.3  69.1  52.2  16.9     15.166667   288.316667
# 20  20160621  62.6  71.4  50.4  21.0     17.000000   290.150000
# 21  20160622  61.7  70.2  55.4  14.8     16.500000   289.650000
# 22  20160623  60.9  67.1  54.9  12.2     16.055556   289.205556
# 23  20160624  61.1  68.9  56.7  12.2     16.166667   289.316667
# 24  20160625  65.7  75.4  57.9  17.5     18.722222   291.872222
# 25  20160626  69.6  77.7  60.3  17.4     20.888889   294.038889
# 26  20160627  60.7  70.0  57.6  12.4     15.944444   289.094444
# 27  20160628  65.4  73.0  55.8  17.2     18.555556   291.705556
# 28  20160629  65.8  73.2  59.7  13.5     18.777778   291.927778
# 29  20160630  65.7  72.7  59.2  13.5     18.722222   291.872222

# %%
# reset the index
warm_temps = warm_temps.reset_index(drop=True)
warm_temps
# Out:
#     YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS  TEMP_KELVIN
# 0   20160615  63.4  70.3  49.3  21.0     17.444444   290.594444
# 1   20160617  60.4  70.7  55.9  14.8     15.777778   288.927778
# 2   20160620  59.3  69.1  52.2  16.9     15.166667   288.316667
# 3   20160621  62.6  71.4  50.4  21.0     17.000000   290.150000
# 4   20160622  61.7  70.2  55.4  14.8     16.500000   289.650000
# 5   20160623  60.9  67.1  54.9  12.2     16.055556   289.205556
# 6   20160624  61.1  68.9  56.7  12.2     16.166667   289.316667
# 7   20160625  65.7  75.4  57.9  17.5     18.722222   291.872222
# 8   20160626  69.6  77.7  60.3  17.4     20.888889   294.038889
# 9   20160627  60.7  70.0  57.6  12.4     15.944444   289.094444
# 10  20160628  65.4  73.0  55.8  17.2     18.555556   291.705556
# 11  20160629  65.8  73.2  59.7  13.5     18.777778   291.927778
# 12  20160630  65.7  72.7  59.2  13.5     18.722222   291.872222

# %%
# Find the mean temperatures (in Celsius) for the last seven days of June

data["TEMP_CELSIUS"].loc[data["YEARMODA"] >= 20160624].mean()
# Out:
# 18.253968253968257

# %% [markdown]
# Dealing with missing data

# %%
# Drop no data values based on the MIN column

warm_temps_clean = warm_temps.dropna(subset=["MIN"])
warm_temps_clean
# Out:
#     YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS  TEMP_KELVIN
# 0   20160615  63.4  70.3  49.3  21.0     17.444444   290.594444
# 1   20160617  60.4  70.7  55.9  14.8     15.777778   288.927778
# 2   20160620  59.3  69.1  52.2  16.9     15.166667   288.316667
# 3   20160621  62.6  71.4  50.4  21.0     17.000000   290.150000
# 4   20160622  61.7  70.2  55.4  14.8     16.500000   289.650000
# 5   20160623  60.9  67.1  54.9  12.2     16.055556   289.205556
# 6   20160624  61.1  68.9  56.7  12.2     16.166667   289.316667
# 7   20160625  65.7  75.4  57.9  17.5     18.722222   291.872222
# 8   20160626  69.6  77.7  60.3  17.4     20.888889   294.038889
# 9   20160627  60.7  70.0  57.6  12.4     15.944444   289.094444
# 10  20160628  65.4  73.0  55.8  17.2     18.555556   291.705556
# 11  20160629  65.8  73.2  59.7  13.5     18.777778   291.927778
# 12  20160630  65.7  72.7  59.2  13.5     18.722222   291.872222

# %% [markdown]
# Data type conversions

# %% [markdown]
# Be careful with type conversions from floating point values to integers. The conversion simply drops the stuff to the right of the decimal point, so all values are rounded down to the nearest whole number. For example, 99.99 will be truncated to 99 as an integer, when it should be rounded up to 100.
#
# Chaining the round and type conversion functions solves this issue as the .round(0).astype(int) command first rounds the values with zero decimals and then converts those values into integers.

# %%
print("Original values:")
data["TEMP"].head()
# Out:
# Original values:
# 0    65.5
# 1    65.8
# 2    68.4
# 3    57.5
# 4    51.4
# Name: TEMP, dtype: float64

# %%
print("Truncated integer values:")
data["TEMP"].astype(int).head()
# Out:
# Truncated integer values:
# 0    65
# 1    65
# 2    68
# 3    57
# 4    51
# Name: TEMP, dtype: int64

# %%
print("Rounded integer values:")
data["TEMP"].round(0).astype(int).head()
# Out:
# Rounded integer values:
# 0    66
# 1    66
# 2    68
# 3    58
# 4    51
# Name: TEMP, dtype: int64

# %% [markdown]
# Unique values

# %%
# Get unique celsius values
unique = data["TEMP"].unique()
list(unique)
# Out:
# [65.5,
#  65.8,
#  68.4,
#  57.5,
#  51.4,
#  52.2,
#  56.9,
#  54.2,
#  49.4,
#  49.5,
#  54.0,
#  55.4,
#  58.3,
#  59.7,
#  63.4,
#  57.8,
#  60.4,
#  57.3,
#  56.3,
#  59.3,
#  62.6,
#  61.7,
#  60.9,
#  61.1,
#  65.7,
#  69.6,
#  60.7,
#  65.4]

# %%
# no. of unique temps
unique_temps = len(unique)
print(f"There were {unique_temps} days with unique mean temperatures in June 2016.")
# Out:
# There were 28 days with unique mean temperatures in June 2016.

# %% [markdown]
# Sorting data

# %%
# Sort ascending vased on temp
data.sort_values(by="TEMP")
# Out:
#     YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS  TEMP_KELVIN
# 8   20160609  49.4  54.1  45.7   8.4      9.666667   282.816667
# 9   20160610  49.5  55.9  43.0  12.9      9.722222   282.872222
# 4   20160605  51.4  58.3  43.2  15.1     10.777778   283.927778
# 5   20160606  52.2  59.7  42.8  16.9     11.222222   284.372222
# 10  20160611  54.0  62.1  41.7  20.4     12.222222   285.372222
# 7   20160608  54.2  60.4  47.5  12.9     12.333333   285.483333
# 11  20160612  55.4  64.2  46.0  18.2     13.000000   286.150000
# 18  20160619  56.3  59.2  54.1   5.1     13.500000   286.650000
# 6   20160607  56.9  65.1  45.9  19.2     13.833333   286.983333
# 17  20160618  57.3  62.8  54.0   8.8     14.055556   287.205556
# 3   20160604  57.5  70.9  47.3  23.6     14.166667   287.316667
# 15  20160616  57.8  67.5  55.6  11.9     14.333333   287.483333
# 12  20160613  58.3  68.2  47.3  20.9     14.611111   287.761111
# 19  20160620  59.3  69.1  52.2  16.9     15.166667   288.316667
# 13  20160614  59.7  67.8  47.8  20.0     15.388889   288.538889
# 16  20160617  60.4  70.7  55.9  14.8     15.777778   288.927778
# 26  20160627  60.7  70.0  57.6  12.4     15.944444   289.094444
# 22  20160623  60.9  67.1  54.9  12.2     16.055556   289.205556
# 23  20160624  61.1  68.9  56.7  12.2     16.166667   289.316667
# 21  20160622  61.7  70.2  55.4  14.8     16.500000   289.650000
# 20  20160621  62.6  71.4  50.4  21.0     17.000000   290.150000
# 14  20160615  63.4  70.3  49.3  21.0     17.444444   290.594444
# 27  20160628  65.4  73.0  55.8  17.2     18.555556   291.705556
# 0   20160601  65.5  73.6  54.7  18.9     18.611111   291.761111
# 24  20160625  65.7  75.4  57.9  17.5     18.722222   291.872222
# 29  20160630  65.7  72.7  59.2  13.5     18.722222   291.872222
# 1   20160602  65.8  80.8  55.0  25.8     18.777778   291.927778
# 28  20160629  65.8  73.2  59.7  13.5     18.777778   291.927778
# 2   20160603  68.4  77.9  55.6  22.3     20.222222   293.372222
# 25  20160626  69.6  77.7  60.3  17.4     20.888889   294.038889

# %%
# Sort dataframe, descending
data.sort_values(by="TEMP", ascending=False)
# Out:
#     YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS  TEMP_KELVIN
# 25  20160626  69.6  77.7  60.3  17.4     20.888889   294.038889
# 2   20160603  68.4  77.9  55.6  22.3     20.222222   293.372222
# 1   20160602  65.8  80.8  55.0  25.8     18.777778   291.927778
# 28  20160629  65.8  73.2  59.7  13.5     18.777778   291.927778
# 29  20160630  65.7  72.7  59.2  13.5     18.722222   291.872222
# 24  20160625  65.7  75.4  57.9  17.5     18.722222   291.872222
# 0   20160601  65.5  73.6  54.7  18.9     18.611111   291.761111
# 27  20160628  65.4  73.0  55.8  17.2     18.555556   291.705556
# 14  20160615  63.4  70.3  49.3  21.0     17.444444   290.594444
# 20  20160621  62.6  71.4  50.4  21.0     17.000000   290.150000
# 21  20160622  61.7  70.2  55.4  14.8     16.500000   289.650000
# 23  20160624  61.1  68.9  56.7  12.2     16.166667   289.316667
# 22  20160623  60.9  67.1  54.9  12.2     16.055556   289.205556
# 26  20160627  60.7  70.0  57.6  12.4     15.944444   289.094444
# 16  20160617  60.4  70.7  55.9  14.8     15.777778   288.927778
# 13  20160614  59.7  67.8  47.8  20.0     15.388889   288.538889
# 19  20160620  59.3  69.1  52.2  16.9     15.166667   288.316667
# 12  20160613  58.3  68.2  47.3  20.9     14.611111   287.761111
# 15  20160616  57.8  67.5  55.6  11.9     14.333333   287.483333
# 3   20160604  57.5  70.9  47.3  23.6     14.166667   287.316667
# 17  20160618  57.3  62.8  54.0   8.8     14.055556   287.205556
# 6   20160607  56.9  65.1  45.9  19.2     13.833333   286.983333
# 18  20160619  56.3  59.2  54.1   5.1     13.500000   286.650000
# 11  20160612  55.4  64.2  46.0  18.2     13.000000   286.150000
# 7   20160608  54.2  60.4  47.5  12.9     12.333333   285.483333
# 10  20160611  54.0  62.1  41.7  20.4     12.222222   285.372222
# 5   20160606  52.2  59.7  42.8  16.9     11.222222   284.372222
# 4   20160605  51.4  58.3  43.2  15.1     10.777778   283.927778
# 9   20160610  49.5  55.9  43.0  12.9      9.722222   282.872222
# 8   20160609  49.4  54.1  45.7   8.4      9.666667   282.816667

# %% [markdown]
# Writing data to file

# %%
# define output filename
output_fp = "Kumpula_temps_June_2016.csv"

# save df to csv
data.to_csv(output_fp, sep=",")

# %%
# Instead remove index and and have 1 decimal in the floating point number

# define output fn
output_fp2 = "Kumpula_temps_above15_June_2016.csv"

# save to csv
warm_temps.to_csv(output_fp2, sep=",", index=False, float_format="%.1f")

# %% [markdown]
# # Exercise 5

# %%
import pandas as pd

# %%
# import data
url = "https://github.com/Geo-Python-2022/Exercise-5/blob/main/data/6153237444115dat.csv!raw=TRUE"
df = [1, 2, 3]

# %%
df = [1, 2, 3]
